# %%
from music21 import *
# Out:
#
# Music21 v.4 is the last version that will support Python 2.
# Please start using Python 3 instead.
#
# Set music21.environment.UserSettings()['warnings'] = 0
# to disable this message.

# %%
fp='../Maple-Leaf-Rag.mid'
streamScore = midi.translate.midiFilePathToStream(fp)

# %%
mf = midi.MidiFile()
mf.open(str(fp))
mf.read()
mf.close()
len(mf.tracks)

mt1 = mf.tracks[0]
mt2 = mf.tracks[1]
s1 = midi.translate.midiTrackToStream(mt1)
s2 = midi.translate.midiTrackToStream(mt2)

# %%
#b = corpus.parse('bach/bwv66.6')
#sp = midi.realtime.StreamPlayer(streamScore)
#sp.play()

# %%
streamScore.plot('pianoroll')

# %%
 streamScore.plot('histogram', 'pitch')

# %%
p = graph.plot.WindowedKey(streamScore.parts[0])
p.id
p.run()

# %%
#Equal number of measures for each section
a=streamScore.parts[0].measures(2,17)#.plot()
b=streamScore.parts[0].measures(34,49)#.plot()
c=streamScore.parts[0].measures(82,97)#.plot()
d=streamScore.parts[0].measures(114,129)#.plot()

realtime_a = midi.realtime.StreamPlayer(a)
realtime_b = midi.realtime.StreamPlayer(b)
realtime_c = midi.realtime.StreamPlayer(c)
realtime_d = midi.realtime.StreamPlayer(d)

#ss.play()

# %%
mdata = corpus.search('Maple')

# %%
mdata[0].sourcePath
piece=corpus.parse('1376-1475.abc')

# %%
piece.plot()

# %%
#%load_ext music21.ipython21.ipExtension
#environment.set('musicxmlPath', '/path/to/application')
#piece.show(fmt='musicxml',app='musescore')
# Out:
# ---------------------------------------------------------------------------
# StreamException                           Traceback (most recent call last)
# <ipython-input-13-76b5bd0bb936> in <module>()
#       1 #%load_ext music21.ipython21.ipExtension
#       2 #environment.set('musicxmlPath', '/path/to/application')
# ----> 3 piece.show(fmt='musicxml',app='musescore')
#
# /usr/local/lib/python2.7/dist-packages/music21/stream/__init__.pyc in show(self, fmt, app)
#   13039             return Stream.show(self, fmt, app)
#   13040         elif common.runningUnderIPython():
# > 13041             return Stream.show(self, fmt, app)
#   13042         else:
#   13043             for s in self.scores:
#
# /usr/local/lib/python2.7/dist-packages/music21/stream/__init__.pyc in show(self, *args, **kwargs)
#     255         if self.isSorted is False and self.autoSort:
#     256             self.sort()
# --> 257         return super(Stream, self).show(*args, **kwargs)
#     258
#     259     #---------------------------------------------------------------------------
#
# /usr/local/lib/python2.7/dist-packages/music21/base.pyc in show(self, fmt, app, **keywords)
#    2627                                  app=app,
#    2628                                  subformats=subformats,
# -> 2629                                  **keywords)
#    2630
#    2631     #--------------------------------------------------------------------------
#
# /usr/local/lib/python2.7/dist-packages/music21/converter/subConverters.pyc in show(self, obj, fmt, app, subformats, **keywords)
#     881         Override to do something with png...
#     882         '''
# --> 883         returnedFilePath = self.write(obj, fmt, subformats=subformats, **keywords)
#     884         if subformats is not None:
#     885             if 'png' in subformats:
#
# /usr/local/lib/python2.7/dist-packages/music21/converter/subConverters.pyc in write(self, obj, fmt, fp, subformats, **keywords)
#     862
#     863         generalExporter = m21ToXml.GeneralObjectExporter(obj)
# --> 864         dataBytes = generalExporter.parse()
#     865         fp = self.writeDataStream(fp, dataBytes)
#     866
#
# /usr/local/lib/python2.7/dist-packages/music21/musicxml/m21ToXml.pyc in parse(self, obj)
#     329         if obj is None:
#     330             obj = self.generalObj
# --> 331         outObj = self.fromGeneralObject(obj)
#     332         return self.parseWellformedObject(outObj)
#     333
#
# /usr/local/lib/python2.7/dist-packages/music21/musicxml/m21ToXml.pyc in fromGeneralObject(self, obj)
#     364             if cM in classes:
#     365                 meth = getattr(self, methName)
# --> 366                 outObj = meth(obj)
#     367                 break
#     368         if outObj is None:
#
# /usr/local/lib/python2.7/dist-packages/music21/musicxml/m21ToXml.pyc in fromStream(self, st)
#     454             else:
#     455                 bestClef = False
# --> 456             st2 = st.makeNotation(inPlace=False, bestClef=bestClef)
#     457             return self.fromScore(st)
#     458
#
# /usr/local/lib/python2.7/dist-packages/music21/stream/__init__.pyc in makeNotation(self, meterStream, refStreamOrTimeRange, inPlace, bestClef, **subroutineKeywords)
#    5964                 refStreamOrTimeRange=refStreamOrTimeRange,
#    5965                 inPlace=True,
# -> 5966                 bestClef=bestClef)
#    5967
#    5968         measureStream = returnStream.getElementsByClass('Measure').stream()
#
# /usr/local/lib/python2.7/dist-packages/music21/stream/__init__.pyc in makeMeasures(self, meterStream, refStreamOrTimeRange, searchContext, innerBarline, finalBarline, bestClef, inPlace)
#    5715             finalBarline=finalBarline,
#    5716             bestClef=bestClef,
# -> 5717             inPlace=inPlace,
#    5718             )
#    5719
#
# /usr/local/lib/python2.7/dist-packages/music21/stream/makeNotation.pyc in makeMeasures(s, meterStream, refStreamOrTimeRange, searchContext, innerBarline, finalBarline, bestClef, inPlace)
#     596         # NOTE: cannot use coreInsert here for some reason
#     597         if voiceIndex is None:
# --> 598             m.insert(oNew, e)
#     599         else:  # insert into voice specified by the voice index
#     600             m.voices[voiceIndex].insert(oNew, e)
#
# /usr/local/lib/python2.7/dist-packages/music21/stream/__init__.pyc in insert(self, offsetOrItemOrList, itemOrNone, ignoreSort, setActiveSite)
#    1721
#    1722         # checks of element is self; possibly performs additional checks
# -> 1723         self.coreGuardBeforeAddElement(element)
#    1724         # main insert procedure here
#    1725
#
# /usr/local/lib/python2.7/dist-packages/music21/stream/core.pyc in coreGuardBeforeAddElement(self, element, checkRedundancy)
#     320                             'the object ' +
#     321                             '(%s, id()=%s) is already found in this Stream (%s, id()=%s)' %
# --> 322                                                     (element, id(element), self, id(self)))
#     323                 # something was old... delete from _offsetDict
#     324                 # environLocal.warn('stale object')
#
# StreamException: the object (<music21.meter.TimeSignature 2/2>, id()=139925728696400) is already found in this Stream (<music21.stream.Measure 144 offset=542.0>, id()=139925875299472)

# %% [markdown]
# #### Note objects and features

# %%
#Creating note objects and accessing features
myNote_1=music21.note.Note("B-4")#Flat and sharp note examples Bb: note.Note("B-2"), C#:note.Note("C#3")
print('Note created has\n  name:',myNote_1.name,myNote_1.pitch.unicodeName,',octave:',myNote_1.octave,'\n  pitch:', myNote_1.pitch.fullName,'\n  frequency: ',myNote_1.pitch.frequency, 'Hz',',midiNo:',myNote_1.pitch.midi)
#Applying transposition
print('\nNew note obtained by transposing the first by a major third:')
myNote_2=myNote_1.transpose("M3")
print('Note created has\n  name:',myNote_2.name,myNote_2.pitch.unicodeName,',octave:',myNote_2.octave,'\n  pitch:', myNote_2.pitch.fullName,'\n  frequency: ',myNote_2.pitch.frequency, 'Hz',',midiNo:',myNote_2.pitch.midi)
# Out:
# Note created has
#   name: B- B♭ ,octave: 4
#   pitch: B-flat in octave 4
#   frequency:  466.1637615180899 Hz ,midiNo: 70
#
# New note obtained by transposing the first by a major third:
# Note created has
#   name: D D ,octave: 5
#   pitch: D in octave 5
#   frequency:  587.3295358348153 Hz ,midiNo: 74

# %%
#setting duration and lyrics to a note
myNote_2.duration.quarterLength = 3.0
myNote_2.lyric = "We will rock you"

# %% [markdown]
# #### Note streams
# A practical data structure to keep a sequence of notes

# %%
noteStream = music21.stream.Stream()
noteStream.append(myNote_1)
noteStream.append(myNote_2)
noteStream.append(music21.note.Rest(type='whole'))
noteStream.repeatAppend(myNote_1, 4)
noteStream.plot()

# %%
#Accessing notes of a stream
for thisNote in noteStream:
    if not thisNote.isRest:
        print('Name:',thisNote.pitch.unicodeName,',midiNo:',thisNote.pitch.midi)
    else:
        print('Rest, duration',thisNote.duration.quarterLength,' quarters')
# Out:
# Name: B♭ ,midiNo: 70
# Name: D ,midiNo: 74
# Rest, duration 4.0  quarters
# Name: B♭ ,midiNo: 70
# Name: B♭ ,midiNo: 70
# Name: B♭ ,midiNo: 70
# Name: B♭ ,midiNo: 70

# %%
#Quick creation of a note stream
s = music21.converter.parse('tinyNotation: 4/4 C4 D4 E4 F4 G4 A4 B4 c4')
s.plot()

# %%
#Creating interval objects
myInterval = music21.interval.Interval('P5')
print('Interval created: ',myInterval.niceName,',size in semitones:',myInterval.semitones,',complement:',myInterval.complement)
# Out:
# Interval created:  Perfect Fifth ,size in semitones: 7 ,complement: <music21.interval.Interval P4>

# %%
#Different intervals available
for intName in ['d5','A2','A4','P4','m2','M6']:
    iTemp = music21.interval.Interval(intName)
    print(intName,':\t',iTemp.niceName)
# Out:
# d5 :	 Diminished Fifth
# A2 :	 Augmented Second
# A4 :	 Augmented Fourth
# P4 :	 Perfect Fourth
# m2 :	 Minor Second
# M6 :	 Major Sixth

# %%
#Interval between two notes
print('Interval between E4 and A4:',music21.interval.Interval(music21.note.Note('E4'), music21.note.Note('A4')).niceName)
# Out:
# Interval between E4 and A4: Perfect Fourth

# %% [markdown]
# #### Reading scores and processing the content

# %%
#Music21 has a collection of scores (self contained, no need for downloading)
piece = music21.corpus.parse('bach/bwv65.2.xml')
piece.plot()

# %%
#Accessing one part, specific measures and plotting pitch-class histograms
part=piece.parts[0]
print(part.partName)
part.measures(0,8).plot()#plotting piano-roll of measures 0-8 of the first part
part.measures(0,8).plot('histogram', 'pitch')#plotting histogram of that section
# Out:
# Soprano

# %% [markdown]
# available plotting options: http://web.mit.edu/music21/doc/moduleReference/moduleGraphPlot.html#music21.graph.plot.ScatterPitchSpaceQuarterLength

# %%
#You can access the list of files in the corpus
corpusFilePaths = music21.corpus.getCorePaths()#for list of files with specific format: kernFilePaths = corpus.getCorePaths('krn')
print('Number of files in corpus: ',len(corpusFilePaths))
print('\nExample files from the corpus:')
numExamples=4
for k in range(0,len(corpusFilePaths),int(len(corpusFilePaths)/(numExamples-1))):
    print('index ',k,' ',corpusFilePaths[k].split('/')[-2:])
# Out:
# Number of files in corpus:  3178
#
# Example files from the corpus:
# index  0   ['cpebach', 'h186.mxl']
# index  1059   ['palestrina', 'Kyrie_II_00.krn']
# index  2118   ['ryansMammoth', 'OldGraniteStateReel.abc']
# index  3177   ['rinaldo', 'Lascia_chio_pianga.mxl']

# %%
#Downloading a midi file and reading its content
urllib.request.urlretrieve('http://zzaj.web.fc2.com/score/BlueTrain.mid','BlueTrain_Jcoltrane.mid')
blueTrain = music21.converter.parse('BlueTrain_Jcoltrane.mid')

# %%
#Printing parts included
index=0
for part in blueTrain.parts:
    print('index ',index,' ',part.partName)
    index+=1
# Out:
# index  0   Tenor Saxophone
# index  1   Trumpet
# index  2   Trombone
# index  3   Piano
# index  4   Acoustic Bass
# index  5   Piano

# %%
#Printing the some measures (walking bass part of the bass line)
blueTrain.parts[4].measures(26,36).plot()

# %% [markdown]
# For another Music21 introduction notebook:
# http://nbviewer.ipython.org/github/mantaraya36/240E-ipython/blob/master/Symbolic%20MIR%20Using%20Music21.ipynb
